# %% [markdown]
# <a href="https://colab.research.google.com/github/vibhubhatia007/AllAboutML/blob/master/IP_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image

# %%
urls = ["https://images.unsplash.com/photo-1488190211105-8b0e65b80b4e?ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&ixlib=rb-1.2.1&auto=format&fit=crop&w=1051&q=80"]

for url in urls :
  image = io.imread(url)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  cv2_imshow(image_2)
  print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=1051x701 at 0x7F55D713BAC8>

# %%
urls = ["https://images.unsplash.com/photo-1488190211105-8b0e65b80b4e?ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&ixlib=rb-1.2.1&auto=format&fit=crop&w=1051&q=80"]

for url in urls :
  image = io.imread(url)
  cv2_imshow(image)
  print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=1051x701 at 0x7F55DFCD2CC0>

# %%
#image negative
image = io.imread(url) 
img_bgr = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  
img_neg = 1 - img_bgr 
  
plt.imshow(img_neg) 
plt.show()

# %%
#log transformation
c = 255 / np.log(1 + np.max(image_2)) 
log_image = c * (np.log(image_2 + 1)) 
   
log_image = np.array(log_image, dtype = np.uint8) 
   
image_2 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)
plt.imshow(image_2) 
plt.show() 
log_image = cv.cvtColor(log_image, cv.COLOR_BGR2RGB)
plt.imshow(log_image) 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
#inverse log transformation
c = 255 / np.log(1 + np.max(image_2)) 
log_image = c * (1 /(np.log(image_2 + 1))) 
   
log_image = np.array(log_image, dtype = np.uint8) 
   
image_2 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)
plt.imshow(image_2) 
plt.show() 
log_image = cv.cvtColor(log_image, cv.COLOR_BGR2RGB)
plt.imshow(log_image) 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
image_2 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)

# Power Law Transform for value 0.8
gamma_corrected = np.array(255*(image_2 / 255) ** 0.8, dtype = 'uint8') 

gamma_corrected = cv.cvtColor(gamma_corrected, cv.COLOR_BGR2RGB)
plt.imshow(gamma_corrected) 
plt.show()

# Power Law Transform for value 0.55
gamma_corrected = np.array(255*(image_2 / 255) ** 0.55, dtype = 'uint8') 

gamma_corrected = cv.cvtColor(gamma_corrected, cv.COLOR_BGR2RGB)
plt.imshow(gamma_corrected) 
plt.show()
